# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import requests

# %matplotlib inline

# Imports in order to be able to use Plotly offline.
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0

portfolio_df = pd.read_excel('my_stocks_acquisition_dates_costs.xlsx', sheet_name = 'Sample')

portfolio_df.head(10)
# Out:
# 5.1.0
#          Date Ticker  Quantity  Unit Cost  Cost Basis Start of Year Trx Type  \
# 0  2021-07-30   ASML       2.0   755.3750   1510.7500    2021-01-01      Buy
# 1  2021-07-29   ASML      -3.0   738.4535  -2215.3605    2021-01-01     Sell
# 2  2021-07-21   ASML       3.0   679.4800   2038.4400    2021-01-01      Buy
# 3  2021-07-19   ASML      -3.0   702.8006  -2108.4018    2021-01-01     Sell
# 4  2021-05-06   ASML       1.0   617.6532    617.6532    2021-01-01      Buy
# 5  2021-04-07   ASML       2.0   644.9385   1289.8770    2021-01-01      Buy
# 6  2021-04-08    CCL      10.0    28.5568    285.5680    2021-01-01      Buy
# 7  2021-03-05    CCL       5.0    29.1583    145.7915    2021-01-01      Buy
# 8  2021-05-10   COIN      -1.0   253.8700   -253.8700    2021-01-01     Sell
# 9  2021-05-06   COIN      -1.0   279.5300   -279.5300    2021-01-01     Sell
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# ...

# %%
# Get sp 500 index from min and max time range 
# Get the closing price of ASML at the max date
# Get the average cost basis per share and compare w/ closing price of ASML at max date for the ticker return rate
# Factor in realized gains/losses along the way (proceeds - it should be cost basis before sell * % of shares sold)


def ticker_vs_index_return(dataFrame, startDate, endDate):
    # Filter dataFrame by startDate and endDate (if sell happens before buy, then just omit)    
    
    # hashmap {ticker: {cost basis, number of shares, gains/losses, minDate, maxDate}}
    tickerMap = {}
    print(len(dataFrame.index))

    # iterate from back to front (earliest to latest)
    for i in range(len(dataFrame.index) - 1, -1, -1):
        # row
        row = dataFrame.iloc[i]

        acqDate = row['Date']
        ticker = row['Ticker']
        trxType = row['Trx Type']
        unitCost = row['Unit Cost']
        quantityShares = row['Quantity']
        costBasis = row['Cost Basis']

        print(row)
        print(acqDate)
        print(ticker)
        print(trxType)
        print(unitCost)
        print(quantityShares)
        print(costBasis)
    
    
ticker_vs_index_return(portfolio_df, 0, 0)


    # if not in map, create ticker and the min Date
    # check max date     
    # add cost basis for buy
    # subtract from cost basis for sell
        # cost basis can never be negative, it can at worst be 0
        # take average cost basis and subtract by number of shares sold, if proceeds higher (negative) - gain, otherwise loss        

# Get S&P 500 index of the timelines 
# Get the average cost basis per share and compare w/ closing price of all hashmap at max date for the ticker return rate
# Out:
# 23
# Date             2021-03-16 00:00:00
# Ticker                           VDE
# Quantity                         2.0
# Unit Cost                      74.62
# Cost Basis                    149.24
# Start of Year    2021-01-01 00:00:00
# Trx Type                         Buy
# Unnamed: 7                       NaN
# Unnamed: 8                       NaN
# Unnamed: 9                       NaN
# Name: 22, dtype: object
# 2021-03-16 00:00:00
# VDE
# Buy
# 74.62
# 2.0
# 149.24
# Date                      2021-04-16
# Ticker                           VDE
# Quantity                         5.0
# Unit Cost                    68.0198
# Cost Basis                   340.099
# Start of Year    2021-01-01 00:00:00
# Trx Type                         Buy
# Unnamed: 7                       NaN
# Unnamed: 8                       NaN
# Unnamed: 9                       NaN
# Name: 21, dtype: object
# 2021-04-16
# VDE
# Buy
# 68.0198
# 5.0
# 340.09900000000005
# Date                      2021-06-21
# ...
